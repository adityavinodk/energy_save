# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sc
import seaborn as sns
import math

# %%
data = pd.read_csv('dataset.csv')
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 32 columns):
# ApplStandard                397 non-null object
# Brand                       397 non-null object
# Cap                         397 non-null float64
# Combination                 397 non-null bool
# Control                     397 non-null object
# Country                     397 non-null object
# Depth                       223 non-null float64
# Height                      223 non-null float64
# Model No                    397 non-null object
# Family Name                 106 non-null object
# N-Standard                  397 non-null object
# New CEC                     397 non-null int64
# New SRI                     397 non-null float64
# New Star                    397 non-null float64
# Prog Name                   397 non-null object
# Prog Time                   397 non-null float64
# Sold_in                     387 non-null object
# SubmitStatus                397 non-null object
# Submit_ID                   397 non-null int64
# Test_Moist_Remove           397 non-null float64
# Tot_Wat_Cons                348 non-null float64
# Type                        397 non-null object
# Width                       223 non-null float64
# ExpDate                     393 non-null object
# GrandDate                   0 non-null float64
# Product Class               397 non-null object
# Availability Status         397 non-null object
# Product Website             199 non-null object
# Representative Brand URL    211 non-null object
# Old Star Rating             0 non-null float64
# Star Image Large            397 non-null object
# Star Image Small            397 non-null object
# dtypes: bool(1), float64(11), int64(2), object(18)
# memory usage: 96.6+ KB
# None
#               Cap       Depth       Height     New CEC     New SRI  \
# count  397.000000  223.000000   223.000000  397.000000  397.000000
# mean     6.701511  586.802691   816.560538  238.392947    3.676230
# std      1.611495   90.215341    91.507124   86.592957    2.480756
# min      1.000000   60.000000    85.000000   52.000000    0.948617
# 25%      5.500000  552.500000   840.000000  160.000000    2.029665
# 50%      7.000000  595.000000   845.000000  228.000000    2.302489
# 75%      8.000000  630.000000   850.000000  311.000000    6.023019
# max     10.000000  870.000000  1092.000000  485.000000   11.003405
#
#          New Star   Prog Time      Submit_ID  Test_Moist_Remove  Tot_Wat_Cons  \
# count  397.000000  397.000000     397.000000         397.000000    348.000000
# mean     3.463476  214.535264  103881.430730          17.502443      7.723489
# std      2.342094   65.791421   11934.533025         242.850106     20.057046
# min      1.000000   50.000000   50351.000000           0.813000      0.000000
# 25%      2.000000  174.600000   94869.000000           4.441000      0.000000
# 50%      2.000000  209.000000  106482.000000           5.538000      0.000000
# 75%      6.000000  257.000000  112706.000000           6.337000      0.000000
# max     10.000000  526.600000  121255.000000        4844.000000    147.800000
#
#             Width  GrandDate  Old Star Rating
# count  223.000000        0.0              0.0
# mean   602.443946        NaN              NaN
# std     70.441882        NaN              NaN
# min     60.000000        NaN              NaN
# 25%    595.000000        NaN              NaN
# 50%    595.000000        NaN              NaN
# 75%    600.000000        NaN              NaN
# max    850.000000        NaN              NaN

# %%
# Let us first find see the features which we might have to drop
print(data.columns.values)

# As we can see here, Grand Date and Old Star Rating are entirely empty so we can drop them
print(data.isnull().sum(), '\n')

# For each of these features, more than 97% of the values are the same, we can drop these as well
print(pd.value_counts(data['N-Standard']), '\n')
print(pd.value_counts(data['SubmitStatus']), '\n')
print(pd.value_counts(data['Product Class']), '\n')
print(pd.value_counts(data['Availability Status']), '\n')
columns = ['Model No', 'Family Name', 'Sold_in', 'N-Standard', 'SubmitStatus', 'Submit_ID', 'GrandDate', 'Product Class', 'Product Website', 'Old Star Rating', 'Star Image Large', 'Star Image Small', 'Availability Status', 'Representative Brand URL']

# Dropping the columns
data.drop(columns, axis=1, inplace=True)
print(data.head(4), '\n')
print(data.info())
# Out:
# ['ApplStandard' 'Brand' 'Cap' 'Combination' 'Control' 'Country' 'Depth'
#  'Height' 'Model No' 'Family Name' 'N-Standard' 'New CEC' 'New SRI'
#  'New Star' 'Prog Name' 'Prog Time' 'Sold_in' 'SubmitStatus' 'Submit_ID'
#  'Test_Moist_Remove' 'Tot_Wat_Cons' 'Type' 'Width' 'ExpDate' 'GrandDate'
#  'Product Class' 'Availability Status' 'Product Website'
#  'Representative Brand URL' 'Old Star Rating' 'Star Image Large'
#  'Star Image Small']
# ApplStandard                  0
# Brand                         0
# Cap                           0
# Combination                   0
# Control                       0
# Country                       0
# Depth                       174
# Height                      174
# Model No                      0
# Family Name                 291
# N-Standard                    0
# New CEC                       0
# New SRI                       0
# New Star                      0
# Prog Name                     0
# Prog Time                     0
# Sold_in                      10
# SubmitStatus                  0
# Submit_ID                     0
# Test_Moist_Remove             0
# Tot_Wat_Cons                 49
# Type                          0
# Width                       174
# ExpDate                       4
# GrandDate                   397
# Product Class                 0
# Availability Status           0
# Product Website             198
# Representative Brand URL    186
# Old Star Rating             397
# Star Image Large              0
# Star Image Small              0
# dtype: int64
#
# AS/NZS 2442.1:1996/Amdt 4:2006    389
# AS/NZS 2442.1:1996                  8
# Name: N-Standard, dtype: int64
#
# Approved    396
# Archived      1
# Name: SubmitStatus, dtype: int64
#
# Single product class    397
# Name: Product Class, dtype: int64
#
# Available      394
# Unavailable      3
# Name: Availability Status, dtype: int64
#
#                               ApplStandard    Brand  Cap  Combination  \
# 0  AS/NZS 2442.2:2000/Amdt 2:2007 (Legacy)  NOUVEAU  4.0        False
# 1  AS/NZS 2442.2:2000/Amdt 2:2007 (Legacy)  Tuscany  6.0        False
# 2  AS/NZS 2442.2:2000/Amdt 2:2007 (Legacy)    ACQUA  6.0        False
# 3  AS/NZS 2442.2:2000/Amdt 2:2007 (Legacy)  TRIESTE  6.0        False
#
#        Control Country  Depth  Height  New CEC   New SRI  New Star  \
# 0        Timer   China    NaN     NaN      180  2.006833       2.0
# 1  Autosensing   China  870.0   650.0      265  2.000000       2.0
# 2  Autosensing   China    NaN     NaN      265  2.000000       2.0
# 3  Autosensing   China  870.0   650.0      265  2.121848       2.0
#
#              Prog Name  Prog Time  Test_Moist_Remove  Tot_Wat_Cons    Type  \
# 0          Strong Heat      200.0              3.115           NaN  Vented
# 1  Extra Dry Full Load      230.0              4.702           NaN  Vented
# 2  Extra Dry/Full Load      230.0              4.702           NaN  Vented
# 3  Extra Dry Full Load      230.0              4.702           NaN  Vented
#
#    Width ExpDate
# 0    NaN     NaN
# 1  600.0     NaN
# 2    NaN     NaN
# 3  600.0     NaN
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 18 columns):
# ApplStandard         397 non-null object
# Brand                397 non-null object
# Cap                  397 non-null float64
# Combination          397 non-null bool
# Control              397 non-null object
# Country              397 non-null object
# Depth                223 non-null float64
# Height               223 non-null float64
# New CEC              397 non-null int64
# New SRI              397 non-null float64
# New Star             397 non-null float64
# Prog Name            397 non-null object
# Prog Time            397 non-null float64
# Test_Moist_Remove    397 non-null float64
# Tot_Wat_Cons         348 non-null float64
# Type                 397 non-null object
# Width                223 non-null float64
# ExpDate              393 non-null object
# dtypes: bool(1), float64(9), int64(1), object(7)
# memory usage: 53.2+ KB
# None

# %%
# Fill up missing value columns
missing_values_columns = [column for column in data.columns.values if data[column].isnull().sum()>0]
print(missing_values_columns)

# Firstly we shall combine Brand and Country into a single column
Brand_Country = []
for index, row in data.iterrows():
    if len(row['Country'])>1: 
        Brand_Country.append((row['Brand'][:2] + row['Country'][0][:1] + row['Country'][1][:1]).upper())
    else: 
        Brand_Country.append((row['Brand'][:2] + row['Country'][0][:1]).upper())
data['Brand_Country'] = Brand_Country
    
# To fill missing values in Depth
mode_depth_overall = data['Depth'].value_counts().index[0]
data['Depth'] = data['Depth'].fillna(0)
for index, row in data.iterrows():
    if int(row['Depth']) == 0:
        brand_country_mode = int(data.loc[data['Brand_Country']==row['Brand_Country']]['Depth'].mode().values[0])
        country_mode = int(data.loc[data['Country']==row['Country']]['Depth'].mode().values[0])
        if brand_country_mode!=0:
            data.at[index, 'Depth'] = brand_country_mode
        elif country_mode!=0:
            data.at[index, 'Depth'] = country_mode
        else: 
            data.at[index, 'Depth'] = mode_depth_overall
    else: 
        data.at[index, 'Depth'] = int(data.at[index, 'Depth'])
data['Depth'] = data['Depth'].astype(int)

# To fill missing values in Height
mode_height_overall = data['Height'].value_counts().index[0]
data['Height'] = data['Height'].fillna(0)
for index, row in data.iterrows():
    if int(row['Height']) == 0:
        brand_country_mode = int(data.loc[data['Brand_Country']==row['Brand_Country']]['Height'].mode().values[0])
        country_mode = int(data.loc[data['Country']==row['Country']]['Height'].mode().values[0])
        if brand_country_mode!=0:
            data.at[index, 'Height'] = brand_country_mode
        elif country_mode!=0:
            data.at[index, 'Height'] = country_mode
        else: 
            data.at[index, 'Height'] = mode_depth_overall
    else: 
        data.at[index, 'Height'] = int(data.at[index, 'Height'])
data['Height'] = data['Height'].astype(int)

# For total water consumption, since the mode value is 0, we will fill the empty values with 0
data['Tot_Wat_Cons'] = data['Tot_Wat_Cons'].fillna(0)
data['Tot_Wat_Cons'] = data['Tot_Wat_Cons'].astype(int)

# To fill missing values in Width
mode_height_overall = data['Width'].value_counts().index[0]
data['Width'] = data['Width'].fillna(0)
for index, row in data.iterrows():
    if int(row['Width']) == 0:
        brand_country_mode = int(data.loc[data['Brand_Country']==row['Brand_Country']]['Width'].mode().values[0])
        country_mode = int(data.loc[data['Country']==row['Country']]['Width'].mode().values[0])
        if brand_country_mode!=0:
            data.at[index, 'Width'] = brand_country_mode
        elif country_mode!=0:
            data.at[index, 'Width'] = country_mode
        else: 
            data.at[index, 'Width'] = mode_depth_overall
    else: 
        data.at[index, 'Width'] = int(data.at[index, 'Width'])
data['Width'] = data['Width'].astype(int)

# Filling up missing ExpDate values
mode_year = int(data.ExpDate.value_counts().index[0].split('/')[2])
data.ExpDate = data.ExpDate.fillna('0')
for index, row in data.iterrows():
    if data.at[index, 'ExpDate']:
        if len(data.at[index, 'ExpDate'].split('/'))==3:
            data.at[index, 'ExpDate'] = data.at[index, 'ExpDate'].split('/')[2]
        else:
            data.at[index, 'ExpDate'] = mode_year

data['ExpDate'] = data['ExpDate'].astype(int)
data['Cap'] = data['Cap'].astype(int)
data['New SRI'] = data['New SRI'].astype(int)
data['New Star'] = data['New Star'].astype(int)
data['Prog Time'] = data['Prog Time'].astype(int)
data['Test_Moist_Remove'] = data['Test_Moist_Remove'].astype(int)
# Out:
# ['Depth', 'Height', 'Tot_Wat_Cons', 'Width', 'ExpDate']

# %%
# As we can see we have removed all the null values are removed, now we must convert all the other data type
# to int type, by mapping boolean and objects to int
ApplStandard_types = {'AS/NZS 2442.2:2000/Amdt 2:2007 (Legacy)': 0, 'Greenhouse and Energy Minimum Standards (Rotary Clothes Dryers) Determination 2012': 1, 'Greenhouse and Energy Minimum Standards (Rotary Clothes Dryers) Determination 2015': 2, 'AS/NZS 2442.2:2000/Amdt 2:2007': 3}
data['ApplStandard'] = data['ApplStandard'].map(ApplStandard_types).astype(int)
data['Combination'] = data['Combination'].map({False: 0, True: 1}).astype(int)
data['Control'] = data['Control'].map({'Timer': 0, 'Autosensing': 1, 'Manual': 2}).astype(int)
data['Type'] = data['Type'].map({'Condenser': 0, 'Vented': 1}).astype(int)
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 19 columns):
# ApplStandard         397 non-null int64
# Brand                397 non-null object
# Cap                  397 non-null int64
# Combination          397 non-null int64
# Control              397 non-null int64
# Country              397 non-null object
# Depth                397 non-null int64
# Height               397 non-null int64
# New CEC              397 non-null int64
# New SRI              397 non-null int64
# New Star             397 non-null int64
# Prog Name            397 non-null object
# Prog Time            397 non-null int64
# Test_Moist_Remove    397 non-null int64
# Tot_Wat_Cons         397 non-null int64
# Type                 397 non-null int64
# Width                397 non-null int64
# ExpDate              397 non-null int64
# Brand_Country        397 non-null object
# dtypes: int64(15), object(4)
# memory usage: 59.0+ KB
# None

# %%
# Let's extract important program types from the dryer
for i in range(len(data)):
    program = data.at[i, 'Prog Name']
    if '/' in program:
        types = program.split('/')
        program = ''
        for t in types:
            program+=t+' '
    if ',' in program:
        types = program.split(',')
        program = ''
        for t in types:
            program+=t+' '
    keywords = program.split(' ')
    features = []
    for i in keywords: 
        i = i.strip()
        if i not in ['', '-']: features.append(i)
    print(features)
# Out:
# ['Strong', 'Heat']
# ['Extra', 'Dry', 'Full', 'Load']
# ['Extra', 'Dry', 'Full', 'Load']
# ['Extra', 'Dry', 'Full', 'Load']
# ['11', 'Cottons', 'Cupboard', 'Dry']
# ['11', 'Cottons', 'Cupboard', 'Dry']
# ['11', 'Cottons', 'Cupboard', 'Dry']
# ['11', 'Cotton', 'Cupboard', 'Dry']
# ['11', 'Cotton', 'Cupboard', 'Dry']
# ['11', 'Cotton', 'Cupboard', 'Dry']
# ['Cottons', 'Normal', '+']
# ['Cotton', 'Cupboard']
# ['Cottons', 'Extra', 'dry']
# ['Cottons', 'Cupboard', 'Dry', 'Extra']
# ['Cotton', 'Cupboard']
# ['Auto', 'Normal', 'Dry']
# ['Everyday']
# ['Everyday']
# ['Extra', 'dry', 'full', 'heat']
# ['Extra', 'dry', 'full', 'heat']
# ['Extra', 'dry', 'full', 'heat']
# ['Extra', 'dry', 'full', 'heat']
# ['Cotton', '-', 'Extra', 'Dry']
# ['Drying', 'Cotton', 'Extra', 'Dry', 'Drying', 'Level', 'High']
# ['strong']
# ['strong']
# ['full', 'heat']
# ['Full', 'heat', 'Extra', 'dry']
# ['Drying', 'Cotton', 'Extra', 'Dry', 'Drying', 'Level', 'High']
# ['regular', 'extra', 'dry', 'program']
# ['High', 'Heat', 'timer', 'set', 'to', '200']
# ['regular', 'extra', 'dry', 'program']
# ['Drying', 'Cotton', 'Dry', 'Cupboard', 'Spin', '1400rpm']
# ['Cupboard+', "('Extra'", 'for', 'DV-T5U)']
# ['Cupboard+', "('Extra'", 'for', 'DV-T5U)']
# ['Cupboard+', "('Extra'", 'for', 'DV-T5U)']
# ['Cupboard+', "('Extra'", 'for', 'DV-T5U)']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Perm', 'Press', 'Temp', 'High', 'Dryness', 'Dry']
# ['Strong']
# ['Full', 'heart', 'Dry']
# ['Extra', 'Cotton']
# ['Cotton', 'Extra']
# ['Extra', 'Cotton']
# ['Intensive', 'Dry', 'Auto2']
# ['Cottons-Extra', 'Dry', 'Dryness', 'Level', 'Normal']
# ['Cottons-Extra', 'Dry', 'Dryness', 'Level-Normal']
# ['Cottons', 'Normal', 'Plus']
# ['Cottons', 'Normal', 'Plus']
# ['Cottons', 'Normal', 'Plus']
# ['Cottons', 'Normal', 'Plus']
# ['Cottons', 'Normal', 'Plus']
# ['Dry', 'Cotton', 'Extra']
# ['Cottons', 'Cupboard', 'Dry', 'Plus']
# ['Cottons', 'Cupboard', 'Dry', 'Plus']
# ['Cottons', 'Cupboard', 'Dry', 'Plus']
# ['Cottons', 'Cupboard', 'Dry', 'Plus']
# ['Cottons', 'Cupboard', 'Dry', 'Plus']
# ['Extra', 'Cotton']
# ['COTTON', 'EXTRA']
# ['Full', 'heat', 'Extra', 'dry']
# ['Cotton', 'Dry', '&', 'Spin']
# ['Full', 'heat', 'Extra', 'dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cupboard']
# ['Everyday', 'Dry', 'Extra', 'Dry', 'High']
# ['Everyday', 'Dry', 'Extra', 'Dry', 'High']
# ['Everyday', 'Dry', 'Extra', 'Dry', 'High']
# ['Everyday', 'Dry', 'Extra', 'Dry', 'High']
# ['Cottons', 'Extra', 'dry']
# ['Cottons', 'Extra', 'Dry', 'Eco']
# ['Cotton', 'Very', 'Dry', 'fine', 'adjust', '+++']
# ['Cottons', 'Very', 'Dry', 'Fine', 'Adjust', '++']
# ['Cottons', 'Cupboard', 'Dry', 'Extra', 'Adjust', 'drying', 'level', '+3']
# ['Extra', '+', 'Cotton', 'Program.']
# ['Eco', '-', 'Extra', 'Dry']
# ['Cottons', 'Cupboard', 'Dry', 'Extra', 'Fine', 'Adjust', '+++']
# ['Cottons', 'Cupboard', 'Dry', 'Extra', 'Fine', 'Adjust', '++']
# ['Cottons', 'Cupboard', 'Dry', 'Extra', 'Adjust', 'drying', 'level', '+3']
# ['Cottons', 'Normal']
# ['Cotton', '+', 'Extra']
# ['Cotton', 'Extra']
# ['Everyday', 'Dry', 'High', 'Temp']
# ['Everyday', 'Dry', 'High', 'Temp']
# ['Everyday', 'Dry', 'High', 'Temp']
# ['Everyday', 'Dry', 'High', 'Temp']
# ['Everyday', 'Dry', 'High', 'Temp']
# ['program', 'no', '11', 'Eco', 'Cotton', '+', 'dry', 'only', 'option', 'at', 'cupboard', 'dry', 'level']
# ['Automatic', 'Regulator', 'Delicate', 'Energy', 'Saver', 'Fabric', 'Selector', 'on', 'Perm', 'Press', 'Regulator']
# ['Extras', 'Cotton', 'Dry', 'Cupboard']
# ['Extra+Cotton']
# ['Cottons', 'Extra', 'Dry']
# ['Extra+Cotton']
# ['Store', 'Dry']
# ['Cotton', 'Dry', 'Extra', '1400', 'rpm']
# ['Cottons-Extra', 'Dry', 'Dryness', 'Level-Normal']
# ['Standard']
# ['Full', 'Heat', 'Extra', 'Dry']
# ['Standard']
# ['P03', 'Cottons', 'Extra', 'Dry']
# ['eCotton', 'Cupboard', 'Dry']
# ['Drying', 'Extra', 'Dry', 'Extra', 'High', 'Spin']
# ['Store', 'Dry', 'program']
# ['eCotton', 'Cupboard', 'Dry']
# ['Everyday']
# ['Extra', 'Dry']
# ['Normal', 'Dry', '&', 'Max', 'Spin']
# ['Dry']
# ['Extra', '+', 'Cotton']
# ['Intensive', 'dry', 'AUTO2']
# ['Intensive', 'dry', 'AUTO2']
# ['Extra', '+', 'Cotton']
# ['Extra', '+', 'Cotton']
# ['Cottons', 'Extra', 'Dry', 'Max', 'Dryness']
# ['200', 'mins', 'High', 'Heat']
# ['Sensor', 'Dry', 'Normal', 'High']
# ['Sensor', 'Dry', 'Extra', 'High']
# ['Cotton', 'Extra', 'Dry']
# ['Cottons', 'Strong', 'Dry']
# ['Cotton', 'Cupboard']
# ['Cotton', 'Cupboard']
# ['Cottons-Extra', 'Dry']
# ['Cotton', 'Dry', 'Eco', 'Dry', '1200RPM']
# ['Extra', 'Cotton']
# ['Cotton', 'Strong']
# ['Cotton', 'Extra']
# ['Extra', 'Dry']
# ['Regular', 'Temp', 'Medium', 'Dryness', 'Less', 'Dry']
# ['Regular', 'Temp', 'Medium', 'Dryness', 'Less', 'Dry']
# ['Regular', 'Temp', 'Medium', 'Dryness', 'Less', 'Dry']
# ['Regular', 'Temp', 'Medium', 'Dryness', 'Less', 'Dry']
# ['Regular', 'Temp', 'Medium', 'Dryness', 'Less', 'Dry']
# ['Regular', 'Temp', 'Medium', 'Dryness', 'Less', 'Dry']
# ['normal', 'dry', 'auto']
# ['Cottons-Ready', 'to', 'Wear', 'Plus']
# ['Cottons-Extra', 'Dry', 'Dryness', 'Level-Normal']
# ['Cottons-Ready', 'to', 'Wear']
# ['Cotton', 'Very', 'Dry']
# ['normal', 'dry', 'auto']
# ['cotton', 'dry', 'extra']
# ['Air', 'Dry', 'Extra', 'High', 'Spin']
# ['Drying', 'Cottons', 'Dryness', 'Extra', 'Dry']
# ['Drying', 'Cottons', 'Dryness', 'Extra', 'Dry']
# ['Extra', '+', 'Cotton']
# ['A3']
# ['High', 'heat', 'Timer', 'set', 'to', '200']
# ['200', 'minutes', 'Strong', 'Heat']
# ['High', 'heat', 'Timer', 'set', 'to', '200']
# ['High', 'heat', 'Timer', 'set', 'to', '200']
# ['Cotton', 'Extra']
# ['regular', 'extra', 'dry', 'program']
# ['Hot', 'program']
# ['Extra', '+', 'Cotton']
# ['Hot', 'Program']
# ['Hot', 'program']
# ['Normal', 'Dry', 'Boost', 'option']
# ['Cottons', 'Extra', 'Dry']
# ['Dry', 'Only']
# ['Normal', 'Dry', 'Boost', 'option']
# ['Cotton', 'Extra']
# ['Normal', 'Dry', 'Normal', 'temp']
# ['Cottons', 'Normal', 'Plus']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cotton', 'Dry', 'Spin']
# ['Cotton', 'Dry', 'Spin']
# ['Dry', 'Dry', 'program']
# ['Cottons', 'Normal', 'Dry']
# ['GZES150600725131']
# ['Extra', 'Cotton']
# ['Extra', 'DRry', 'full', 'load']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry', 'Eco']
# ['Cottons', 'Extra', 'Dry', 'Eco']
# ['Cotton', 'Drying', 'Level', '3', 'used', 'once', 'per', 'week']
# ['Thermostat']
# ['Full', 'Heat', 'Extra', 'Dry']
# ['Extra']
# ['Extra', '+', 'Cotton']
# ['Cottons', 'Dry', '1400', 'Eco', 'Dry']
# ['EXTRA', 'DRY']
# ['Cottons', 'Dry', '1400', 'Eco', 'Dry']
# ['Cotton', 'Dry', '&', 'Spin']
# ['The', 'tests', 'were', 'carried', 'out', 'on', 'programme', 'EXTRA']
# ['EXTRA']
# ['Cupboard+']
# ['Cupboard+']
# ['Cupboard+']
# ['Cottons', 'Normal', 'Dry']
# ['Cottons', 'Normal', 'dry']
# ['Cotton', 'Energy', 'Dry']
# ['strong']
# ['strong']
# ['200', 'minutes', 'strong', 'heat']
# ['Cottons', 'Extra', 'Dry']
# ['Prog', '11', 'Cottons', 'cupboard', 'dry']
# ['Dry']
# ['Automatic', 'Regular', 'Delicate', 'Energy', 'saver', '-', 'Fabric', 'selector', 'on', 'Delicate']
# ['Delicate', 'Temp', 'Low', 'Dryness', 'Near', 'Dry210']
# ['EXTRA']
# ['Cotton', 'Normal', 'Cupboard']
# ['Air', 'Dry', 'Extra', 'High', 'Spin']
# ['EXTRA']
# ['EXTRA']
# ['EXTRA']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Auto', 'Normal', 'Dry']
# ['Cotton', 'Energy', 'Dry']
# ['Cotton', 'Energy', 'Dry']
# ['Cottons', '60oC', 'Normal+', 'dry']
# ['Extra', 'Cotton']
# ['Extra']
# ['Timer', 'Used']
# ['Timer', 'Used']
# ['Cottons', '60oC', 'Normal+', 'dry']
# ['Cotton', 'Extra']
# ['Cotton', 'Extra']
# ['Cotton', 'Extra', 'dry']
# ['High', 'Heat']
# ['Dry', 'program', '190', 'minutes', '1300', 'RPM']
# ['Everyday', 'Dry', 'High']
# ['Cotton', 'Normal', 'Cupboard']
# ['Intensive', 'dry', 'Cupboard']
# ['Cottons', 'Strong', 'Dry']
# ['Cottons', 'Strong', 'Dry']
# ['Cottons', 'Strong', 'Dry']
# ['Dry', 'Program', '220', 'min', '1200', 'RPM']
# ['Dry', 'program', '220', 'min', '1400rpm']
# ['very', 'dry', '1200', 'spin']
# ['cotton-Extra', 'Dry']
# ['full', 'heat', '160', 'minutes']
# ['Extra', '+', 'Cotton']
# ['Extra', '+', 'Cotton']
# ['Extra+Cotton']
# ['AU']
# ['Everyday', 'Extra', 'Dry', 'High']
# ['Everyday', 'Extra', 'Dry', 'High']
# ['Everyday', 'Extra', 'Dry', 'High']
# ['Everyday']
# ['Program', '1', 'Cotton', 'Extra', 'Dry', 'High', 'Heat']
# ['Program', '1', 'Cotton', 'Extra', 'Dry', 'High', 'Heat']
# ['Program', '1', 'Cotton', 'Extra', 'Dry', 'High', 'Heat']
# ['Program', '1', 'Cotton', 'Extra', 'Dry', 'High', 'Heat']
# ['Cottons', 'Extra', 'Dry', 'Drying', 'Level', 'Normal']
# ['Cottons', 'Extra', 'Dry']
# ['Cotton', 'Cupboard', 'Dry', 'Plus']
# ['Cotton', 'Extra', 'Dry', 'Dryness', 'Level', '3']
# ['Cotton', 'Hanger', 'Dry']
# ['Cotton', 'Hanger', 'Dry']
# ['High', 'Heat', 'Extra', 'Dry']
# ['Dry', 'Only']
# ['Cotten', 'Extra']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Cotton', 'Extra']
# ['HOT', '-', '200min']
# ['program', 'no', '12', 'Cotton']
# ['program', 'no', '12', 'Cotton']
# ['Full', 'heat']
# ['Cottons-Extra', 'Dry']
# ['Cottons-Extra', 'Dry']
# ['Cotton', 'Extra']
# ['Cottons', 'Extra', 'dry']
# ['Extra', 'Cotton']
# ['Cotton', '+', 'Extra']
# ['Prog', '11', 'Cottons', 'cupboard', 'dry']
# ['Strong', 'heat', 'timer', 'set', 'to', '200']
# ['200', 'minutes', 'strong', 'heat', 'program']
# ['Extra+Cotton']
# ['full', 'heat']
# ['Cottons', 'Extra', 'Dry']
# ['Extra', 'Dry']
# ['Extra']
# ['Cottons-Ready', 'to', 'Wear', 'Plus']
# ['Cottons-Ready', 'to', 'Wear']
# ['Cottons-Extra', 'Dry']
# ['Extras', 'cotton', 'dry', 'cupboard']
# ['Cotton', 'Dry-Extra', 'Dry', '1400', 'rpm']
# ['Cotton', 'Dry', 'Spin', '1400', 'RPM']
# ['Cotton', 'Extra']
# ['TBC']
# ['TBC']
# ['TBC']
# ['Cotton', 'Dry', 'Level', '3']
# ['Cotton', 'Dry', 'Level', '3']
# ['Cotton', 'Dry', 'Level', '3']
# ['Everyday', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cupboard', 'Dry', '1400RPM']
# ['Dry']
# ['Cotton', 'Eco', 'Extra', 'High', 'Spin']
# ['Cottons', 'Normal', '+']
# ['Program', 'No.13', 'Cotton', 'Dry', 'Level', '3']
# ['Program', 'No.13', 'Cotton', 'Dry', 'Level', '3']
# ['Thermostat']
# ['Cotton', 'Extra']
# ['TBC']
# ['TBC']
# ['Dry', 'Only']
# ['Strong']
# ['CUPBOARD+']
# ['tbc']
# ['Dry', 'Only']
# ['Sheets', 'Dry']
# ['Sheets', 'Dry']
# ['Sheets', 'Dry']
# ['IHS']
# ['eCotton', 'option', 'Dry', 'Only', 'with', 'Wardrobe', 'dryness', 'level']
# ['Eco', 'Cotton', 'Dry', 'Only', 'Level', 'A3']
# ['Extra', 'Cotton']
# ['Cotton', 'Extra']
# ['Dry', 'Only']
# ['DRY', 'ONLY']
# ['High', 'Heat', 'Timer', 'set', 'to', '200']
# ['Cotton', 'standard']
# ['Program', '11', 'Cotton', 'Drying', 'Level', 'A4']
# ['Cotton', 'Extra']
# ['Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Sensor', 'Dry', 'Extra', 'High']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Drying', 'Cottons', 'Dryness', 'Extra', 'Dry']
# ['Cottons', 'Dry', 'Dryness', 'Extra', 'Dry']
# ['Cottons', 'Dry', 'Dryness', 'Extra', 'Dry']
# ['Cotton', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Hot', 'program']
# ['Extra', 'dry']
# ['Cottons', 'Dry', 'Extra']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Extra', 'Dry']
# ['Cottons', 'Dry', 'Extra']
# ['EXTRA', 'DRY']
# ['Cotton', 'Normal', 'Cupboard']
# ['Cotton', 'Normal', 'Cupboard']
# ['Cotton', 'Normal', 'Cupboard']
# ['Dry', 'Only']
# ['Cotton', 'Normal', 'Cupboard']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Timer', 'set', 'to', '200']
# ['Cotton', 'Extra']
# ['COTTON', 'Normal', 'Dry', 'Level', 'Medium', 'Temp.', 'Energy', 'Saving', 'Dry', 'Option']
# ['Cottons', 'Extra', 'Dry', 'temp']
# ['Cottons', 'Extra', 'Dry', 'temperature']
# ['Cotton', 'standard']
# ['Cotton', 'standard']
# ['Cotton', 'standard']
# ['EXTRA', 'DRY']
# ['Cottons', 'Extra', 'Dry']
# ['Cotton', 'Extra']
# ['Cupboard+']
# ['Cupboard+']
# ['Cupboard+']
# ['Cupboard+']
# ['Cotton', 'Extra']
# ['Cottons', 'Cupboard', 'Dry', 'Plus', 'Drying', 'level', '+2']
# ['Cottons', 'Cupboard', 'Dry', 'Plus', 'Drying', 'level', '+2']
# ['Cottons', 'Cupboard', 'Dry', 'Plus', 'Drying', 'level', '+2']
# ['Full', 'heat']
# ['Cottons', 'Normal', '+']
# ['STRONG']
# ['Extra', 'Cotton']
# ['COTTON', 'EXTRA']
# ['Cottons', 'Extra', 'dry']
# ['Cottons', 'Extra', 'dry']
# ['Cottons', 'Extra', 'dry']
